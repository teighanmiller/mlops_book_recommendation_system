# %%
import pandas as pd

# %%
df = pd.read_csv("/home/ubuntu/notebooks/mlops_book_recommendation_system/data/open_ai_embeddings.csv")

# %%
df
# Out:
#               0         1         2         3         4         5         6  \
# 0     -0.027731  0.042470  0.008717  0.006005  0.003524 -0.011976  0.025499
# 1     -0.033636  0.057242 -0.046693  0.006161 -0.012700 -0.030221  0.000629
# 2     -0.000989  0.046005 -0.038520  0.031684 -0.003147 -0.049453 -0.034260
# 3      0.005111  0.006698  0.006078 -0.008062  0.012402  0.011119 -0.058505
# 4     -0.038795 -0.015637 -0.055804  0.010385 -0.018284  0.015993  0.032960
# ...         ...       ...       ...       ...       ...       ...       ...
# 37055  0.015166  0.064640 -0.022971  0.025832  0.012533  0.005859 -0.022013
# 37056 -0.021004  0.024678 -0.062816  0.034320 -0.007740 -0.010017 -0.008390
# 37057 -0.001714  0.055193 -0.013351 -0.009384 -0.032579  0.045978  0.023400
# 37058  0.003824  0.075715 -0.022526  0.011342 -0.010533  0.002858 -0.019170
# 37059       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...
